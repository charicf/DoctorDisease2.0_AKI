# %%
import os
import sys
from pathlib import Path

import pandas as pd
from ydata_profiling import ProfileReport

sys.path.insert(0, str(Path("").resolve().parents[1]))
from utils.db_manager import MimicDBManager

# %%
db_manager = MimicDBManager(host='localhost', database='mimiciv_db', user='mimic_user', password='mimic_password', port=5454)
table_names = db_manager.retrieve_table_names()
print(len(table_names))
table_names
# Out:
# [2024-05-22 22:22:56,659 - db_manager.py:51 - generate_connection() - INFO Creating connection to PostgreSQL
# 31
# ['mimiciv_hosp.diagnoses_icd',
#  'mimiciv_hosp.d_labitems',
#  'mimiciv_hosp.d_icd_diagnoses',
#  'mimiciv_hosp.d_icd_procedures',
#  'mimiciv_hosp.d_hcpcs',
#  'mimiciv_hosp.admissions',
#  'mimiciv_hosp.drgcodes',
#  'mimiciv_hosp.emar_detail',
#  'mimiciv_hosp.microbiologyevents',
#  'mimiciv_hosp.pharmacy',
#  'mimiciv_hosp.omr',
#  'mimiciv_hosp.poe_detail',
#  'mimiciv_hosp.poe',
#  'mimiciv_hosp.procedures_icd',
#  'mimiciv_hosp.provider',
#  'mimiciv_icu.caregiver',
#  'mimiciv_hosp.patients',
#  'mimiciv_hosp.emar',
#  'mimiciv_hosp.hcpcsevents',
#  'mimiciv_hosp.labevents',
#  'mimiciv_hosp.prescriptions',
#  'mimiciv_hosp.services',
#  'mimiciv_hosp.transfers',
#  'mimiciv_icu.chartevents',
#  'mimiciv_icu.d_items',
#  'mimiciv_icu.datetimeevents',
#  'mimiciv_icu.ingredientevents',
#  'mimiciv_icu.inputevents',
#  'mimiciv_icu.outputevents',
# ...

# %%
[name  for name in table_names if 'mimiciv_icu' in name]
# Out:
# ['mimiciv_icu.caregiver',
#  'mimiciv_icu.chartevents',
#  'mimiciv_icu.d_items',
#  'mimiciv_icu.datetimeevents',
#  'mimiciv_icu.ingredientevents',
#  'mimiciv_icu.inputevents',
#  'mimiciv_icu.outputevents',
#  'mimiciv_icu.procedureevents',
#  'mimiciv_icu.icustays']

# %%
[db_manager.count_rows(table_name=table) for table in db_manager.retrieve_table_names()[:10]]
# Out:
# [4756326,
#  1622,
#  109775,
#  85257,
#  89200,
#  431231,
#  604377,
#  54744789,
#  3228713,
#  13584514]

# %%
table_name = db_manager.retrieve_table_names()[0]
print(table_name)
db_manager.retrieve_id(table_name, id=18207287, id_column="subject_id")
# Out:
# mimiciv_hosp.diagnoses_icd
# /home/charicfc/charic/code/ds_ml/projects/docDisease2_env/project/DoctorDisease2.0_AKI/utils/db_manager.py:100: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql_query, self.generate_connection())
#              hadm_id  seq_num icd_code  icd_version
# subject_id
# 18207287    24201343        4  49390              9
# 18207287    24201343        5  2449               9
# 18207287    24201343        6  V4586              9
# 18207287    24245051        1  78901              9
# 18207287    24245051        2  5722               9
# ...              ...      ...      ...          ...
# 18207287    24032708       12  V442               9
# 18207287    24032708       13  V4586              9
# 18207287    24201343        1  55321              9
# ...

# %%
patient_data = db_manager.retrieve_all("mimiciv_hosp.patients")
patient_data
# Out:
# /home/charicfc/charic/code/ds_ml/projects/docDisease2_env/project/DoctorDisease2.0_AKI/utils/db_manager.py:147: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   response = pd.read_sql_query(sql_query, self.generate_connection())
#         subject_id gender  anchor_age  anchor_year anchor_year_group  \
# 0         10000032      F          52         2180       2014 - 2016
# 1         10000048      F          23         2126       2008 - 2010
# 2         10000068      F          19         2160       2008 - 2010
# 3         10000084      M          72         2160       2017 - 2019
# 4         10000102      F          27         2136       2008 - 2010
# ...            ...    ...         ...          ...               ...
# 299707    19999828      F          46         2147       2017 - 2019
# ...

# %%
patient_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299712 entries, 0 to 299711
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   subject_id         299712 non-null  int64
#  1   gender             299712 non-null  object
#  2   anchor_age         299712 non-null  int64
#  3   anchor_year        299712 non-null  int64
#  4   anchor_year_group  299712 non-null  object
#  5   dod                29076 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 13.7+ MB

# %%
patient_data['dod'] = pd.to_datetime(patient_data['dod'])

# %%
profile = ProfileReport(patient_data, title="Profiling Report")
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v0.0.dev0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-05-23 03:48:00.778999&quot;&gt;&lt;title&gt;Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
